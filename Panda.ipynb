# %% [markdown]
# <a href="https://colab.research.google.com/github/Luffyapo93/Panda/blob/main/Panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TRABAJANDO CON PANDA

# %%
# importando la libreria
import pandas as pd

# %%
# ayuda de panda
help(pd.Series.ilocm)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     .. deprecated:: 2.2.0
#
#        Returning a tuple from a callable is deprecated.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on
#       some value.
#     - A tuple of row and column indexes. The tuple elements consist of one of the
#       above inputs, e.g. ``(0, 1)``.
#
# ...

# %%
diccionario = [{
    'a':2,
    'b':4,
    'c':9
},{
    'a':16,
    'b':12,
    'c':19
}]
df=pd.DataFrame(diccionario)
df
# Out:
#     a   b   c
# 0   2   4   9
# 1  16  12  19

# %% [markdown]
# SERIES

# %%
# crear una serie
serie=pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
serie
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# borrar series o filas
serie2=serie.drop(['a','e'])
serie2
# Out:
# b    2
# c    3
# d    4
# dtype: int64

# %%
# seleccionar filas o series
serie[['b','c']]
# Out:
# b    2
# c    3
# dtype: int64

# %%
# asignacion
serie['f']=6
serie
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
# operadores
serie3 = serie+serie2
serie3
# Out:
# a    NaN
# b    4.0
# c    6.0
# d    8.0
# e    NaN
# f    NaN
# dtype: float64

# %%
# division
series4 = serie/serie2
series4
# Out:
# a    NaN
# b    1.0
# c    1.0
# d    1.0
# e    NaN
# f    NaN
# dtype: float64

# %%
# de otra manera la divicion
serie.div(serie2)
# Out:
# a    NaN
# b    1.0
# c    1.0
# d    1.0
# e    NaN
# f    NaN
# dtype: float64

# %%
# multiplicacion
series5 = serie*serie2
series5
# Out:
# a     NaN
# b     4.0
# c     9.0
# d    16.0
# e     NaN
# f     NaN
# dtype: float64

# %%
# de otra manera la multiplicacion
serie.mul(serie2)
# Out:
# a     NaN
# b     4.0
# c     9.0
# d    16.0
# e     NaN
# f     NaN
# dtype: float64

# %%
# resta
series6 = serie-serie2
series6
# Out:
# a    NaN
# b    0.0
# c    0.0
# d    0.0
# e    NaN
# f    NaN
# dtype: float64

# %%
# Resta usando el método sub con fill_value
series7 = serie.sub(serie2, fill_value=0)
series7
# Out:
# a    1.0
# b    0.0
# c    0.0
# d    0.0
# e    5.0
# f    6.0
# dtype: float64

# %% [markdown]
# DATA FRAME

# %%
datos = {'Alumno':['M Mar','Lucia','Juan','Eva'],'Nota':[20,10,15,8]}
df = pd.DataFrame(datos,columns=['Alumno','Nota'])
df
# Out:
#   Alumno  Nota
# 0  M Mar    20
# 1  Lucia    10
# 2   Juan    15
# 3    Eva     8

# %%
# Borrar la columna 2
df = df.drop(df.columns[1], axis=1)
df

# %%
# borrar la fila 1
df = df.drop(df.index[1])
df
# Out:
#   Alumno  Nota
# 0  M Mar   NaN
# 2   Juan   NaN
# 3    Eva  20.0

# %%
# actualizar la nota de eva 20
df.loc[3, 'Nota'] = 20
df
# Out:
#   Alumno  Nota
# 0  M Mar   NaN
# 1  Lucia   NaN
# 2   Juan   NaN
# 3    Eva  20.0

# %%
# mostrar la fila 0 y 2
df.iloc[[0,2]]
# Out:
#   Alumno  Nota
# 0  M Mar   NaN
# 2   Juan   NaN

# %% [markdown]
# ENTRADA - SALIDA Y ESCRITURA

# %%
# grabar un dataframe
df.to_csv('/content/misDatos.csv', index=False,columns=['Alumno','Nota'])

# %%
# leer el data frame
mis_datos=pd.read_csv('/content/misDatos.csv', header=None,nrows=2)
mis_datos.columns=['Alumno','Nota']
mis_datos.head()
# Out:
#    Alumno  Nota
# 0  Alumno  Nota
# 1   M Mar   NaN
